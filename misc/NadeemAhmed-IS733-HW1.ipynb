# %% [markdown]
# # IS 733 Data Mining (Fall 2022)
# ### Homework 1
# ### Data Wrangling with Baltimore City 911 Report Data
# ### by Nadeem Ahmed

# %% [markdown]
# #### **Question 1**
#
# We start by importing relevant libraries and attempt to summarize the data set before pre-processing. We will also exclude certain columns as they are either constants or have limited value.
#
# **Note 1: Trying to do profiling using Pandas Profiling on this dataset proved to be not fruitful as the library was not able to handle some elements of the dataset and the error produced was "Product space too large to allocate arrays!"**
#
# **Note 2: Cells need to be run in sequence as some variables are reused.**

# %%
# !pip install skimpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: skimpy in /usr/local/lib/python3.7/dist-packages (0.0.5)
# Requirement already satisfied: pandas<2.0.0,>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from skimpy) (1.3.5)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from skimpy) (7.1.2)
# Requirement already satisfied: rich<11.0.0,>=10.9.0 in /usr/local/lib/python3.7/dist-packages (from skimpy) (10.16.2)
# Requirement already satisfied: typeguard<3.0.0,>=2.12.1 in /usr/local/lib/python3.7/dist-packages (from skimpy) (2.13.3)
# Requirement already satisfied: Pygments<3.0.0,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from skimpy) (2.13.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.3.2->skimpy) (2022.2.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas<2.0.0,>=1.3.2->skimpy) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas<2.0.0,>=1.3.2->skimpy) (1.15.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich<11.0.0,>=10.9.0->skimpy) (0.9.1)
# Requirement already satisfied: typing-extensions<5.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from rich<11.0.0,>=10.9.0->skimpy) (4.1.1)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from rich<11.0.0,>=10.9.0->skimpy) (0.4.5)

# %%
import pandas as pd
import plotly.express as px # usig the Plotly plotting engine
from ipywidgets import interact, widgets # For interactive dashboard
from skimpy import skim # A lite library to summarize a dataframe quickly

# %%
columns_excluded = ['Post','Total Incidents','Location 1','vri_name1'] # exclude columns that dont provide value

df = pd.read_csv("https://ruralatlasdataset.s3.amazonaws.com/BPD_Part_1_Victim_Based_Crime_Data.csv", usecols=lambda column: column not in columns_excluded)

#Convert certain columns to categories
df["District"] = df["District"].astype("category")
df["Description"] = df["Description"].astype("category")
df["Weapon"] = df["Weapon"].astype("category")

# %% [markdown]
# We will answer the following bullets by running **skimpy**:
# + Total number of instances/rows
# + Total number of features/columns
# + For each column
#     + Are they numeric/real/continuous or symbolic/discrete types of attributes or belong to temporal or spatial categories
#     + If it is a numeric attribute, what are the min, max, mean, median, and standard deviation of the values
#     + If it is a discrete attribute, what is the total number of unique values?
#     + What is the level of missingness (% of rows with missing values)?

# %%
skim(df)
# Out:
# ╭───────────────────────────────────── skimpy summary ──────────────────────────────────────╮
# │          Data Summary                Data Types               Categories                  │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓ ┏━━━━━━━━━━━━━━━━━━━━━━━┓          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃ ┃ Categorical Variables ┃          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩ ┡━━━━━━━━━━━━━━━━━━━━━━━┩          │
# │ │ Number of rows    │ 292761 │ │ object      │ 7     │ │ Description           │          │
# │ │ Number of columns │ 12     │ │ category    │ 3     │ │ Weapon                │          │
# │ └───────────────────┴────────┘ │ float64     │ 2     │ │ District              │          │
# │                                └─────────────┴───────┘ └───────────────────────┘          │
# │                                          number                                           │
# │ ┏━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━┳━━━━━━━┳━━━━━┳━━━━━┳━━━━━┳━━━━━━┳━━━━━━━━┓  │
# │ ┃           ┃ missing ┃ complete rate ┃ mean ┃ sd    ┃ p0  ┃ p25 ┃ p75 ┃ p100 ┃ hist   ┃  │
# │ ┡━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━╇━━━━━━━╇━━━━━╇━━━━━╇━━━━━╇━━━━━━╇━━━━━━━━┩  │
# │ │ Longitude │    1600 │          0.99 │  -77 │ 0.044 │ -82 │ -77 │ -77 │  -76 │      █ │  │
# │ │ Latitude  │    1600 │          0.99 │   39 │  0.03 │  38 │  39 │  39 │   40 │     █▅ │  │
# │ └───────────┴─────────┴───────────────┴──────┴───────┴─────┴─────┴─────┴──────┴────────┘  │
# │                                         category                                          │
# │ ┏━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━┓  │
# │ ┃                    ┃ missing      ┃ complete rate         ┃ ordered      ┃ unique    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━┩  │
# │ │ Description        │            0 │                     1 │ False        │        14 │  │
# │ │ Weapon             │       230000 │                  0.21 │ False        │         6 │  │
# │ │ District           │            0 │                     1 │ False        │        10 │  │
# │ └────────────────────┴──────────────┴───────────────────────┴──────────────┴───────────┘  │
# ╰─────────────────────────────────────────── End ───────────────────────────────────────────╯

# %% [markdown]
# + What are the three attribute values with the largest count?
#
# We can look at the three categorical variables to get that answer.

# %%
df['Description'].value_counts().head(3)
# Out:
# LARCENY           65508
# COMMON ASSAULT    48061
# BURGLARY          42237
# Name: Description, dtype: int64

# %%
df['District'].value_counts().head(3)
# Out:
# NORTHEAST    44207
# SOUTHEAST    41816
# CENTRAL      33508
# Name: District, dtype: int64

# %%
df['Weapon'].value_counts().head(3)
# Out:
# FIREARM    29036
# OTHER      17313
# KNIFE      10023
# Name: Weapon, dtype: int64

# %% [markdown]
# #### **Question 2:**
#
# Generate a series of plots to describe the temporal pattern (year-to-year, monthly, and day-of-week) of the overall crime incidence aggregating from all geo-locations.
#
# ##### Data Munging
# We will do the following pre-processing of data to increase our ability of filtering and plotting the data.
#
# + Lets add another **"Date"** column to convert **"CrimeDate"** and the **"CrimeTime"** as a datetime object so that we can access its date/time attributes easily.
# + We will remove rows of years in which there is hardly any data. For our purposes, the data to be plotted will only be from 2014-2019. Rest of the years will be removed.

# %%
# Crimetime column has quiet a few empty cells. So we have to fill them up before we convert. Otherwise does not work.

df = df.fillna({
    'CrimeTime' : '0:00:00'
})

# This takes about 20+ secs to execute. There are various other ways to this but ....

df['Date'] = pd.to_datetime(df['CrimeDate'] + ' ' + df['CrimeTime'])

# %%
# Remove rows before 2014 & after 2019
df = df[~((df['Date'] < '2014-01-01') | (df['Date'] > '2019-12-31'))]

# %%
# Perform group by operations for Year, Month and Weekday
df_year = df.groupby(df['Date'].dt.year)
df_month = df.groupby(df['Date'].dt.month)
df_week = df.groupby(df['Date'].dt.weekday)

# %%
# Gives us a Series object with years aggregated across the years
crimes_by_years = df_year.size()
crimes_by_years
# Out:
# Date
# 2014    45307
# 2015    48192
# 2016    48774
# 2017    52163
# 2018    48436
# 2019    45901
# dtype: int64

# %%
# Gives us a Series object with months aggregated across the years
crimes_by_month = df_month.size()

# For plotting purposes we will need to rename the index of the Series objects to actual Months and Days
months = { 1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}
crimes_by_month.rename(index=months, inplace=True)
crimes_by_month
# Out:
# Date
# Jan    22569
# Feb    18295
# Mar    21036
# Apr    23061
# May    25684
# Jun    25741
# Jul    26352
# Aug    26568
# Sep    25635
# Oct    26391
# Nov    23917
# Dec    23524
# dtype: int64

# %%
# Gives us a Series object with days aggregated across the years
crimes_by_days = df_week.size()

# For plotting purposes we will need to rename the index of the Series objects to actual Months and Days
days_of_week = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
crimes_by_days.rename(index=days_of_week, inplace=True)
crimes_by_days
# Out:
# Date
# Mon    42493
# Tue    41708
# Wed    41466
# Thu    41183
# Fri    43024
# Sat    40035
# Sun    38864
# dtype: int64

# %%
#Plot crime aggregate across Years
fig_year = px.line(crimes_by_years, title="Crime aggregate across years")
fig_year.update_layout(showlegend=False)
fig_year.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f492dd53-95e4-4b1e-b33f-cbf29232a3c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f492dd53-95e4-4b1e-b33f-cbf29232a3c4")) {                    Plotly.newPlot(                        "f492dd53-95e4-4b1e-b33f-cbf29232a3c4",                        [{"hovertemplate":"variable=0<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[45307,48192,48774,52163,48436,45901],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{" ...

# %%
#Plot crime aggregate across Months
fig_month = px.line(crimes_by_month, title="Crime aggregate across months")
fig_month.update_layout(showlegend=False)
fig_month.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fa5d2ad8-63c1-41f7-8611-2c4176879d17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa5d2ad8-63c1-41f7-8611-2c4176879d17")) {                    Plotly.newPlot(                        "fa5d2ad8-63c1-41f7-8611-2c4176879d17",                        [{"hovertemplate":"variable=0<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[22569,18295,21036,23061,25684,25741,26352,26568,25635,26391,23917,23524],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outli ...

# %%
#Plot crime aggregate across Days
fig_days = px.line(crimes_by_days,title="Crime aggregate across days")
fig_days.update_layout(showlegend=False)
fig_days.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a8142638-2ae3-4362-bffb-6071cb7bac33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8142638-2ae3-4362-bffb-6071cb7bac33")) {                    Plotly.newPlot(                        "a8142638-2ae3-4362-bffb-6071cb7bac33",                        [{"hovertemplate":"variable=0<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"0","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"0","orientation":"v","showlegend":true,"x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[42493,41708,41466,41183,43024,40035,38864],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"li ...

# %% [markdown]
# #### **Question 3**
#
# Generate a plot describing the distribution of crime type aggregating from all geo-locations and all time periods.

# %%
#Generate an array to capture the Crime Types against Years
crime_series = []
for year in df_year.groups.keys():
    temp_group = df_year.get_group(year)
    temp_group = temp_group['Description'].value_counts()
    temp_group.rename(year, inplace=True)
    crime_series.append(temp_group)

# %%
crimes = pd.DataFrame()

for crime in crime_series:
    crimes = pd.concat([crimes,crime],axis=1)

crimes = crimes.T
crimes.rename_axis('Crimes',axis='columns', inplace=True)
crimes.rename_axis('Years',axis='rows',inplace=True)
crimes
# Out:
# Crimes  AGG. ASSAULT  ARSON  AUTO THEFT  BURGLARY  COMMON ASSAULT  HOMICIDE  \
# Years
# 2014            4264    216        3652      6877            7463       211
# 2015            4763    289        4565      7856            6992       342
# 2016            5149    268        4612      7392            7498       318
# 2017            5843    265        4669      8094            8751       342
# 2018            5604    126        4226      6212            8369       309
# 2019            5642    106        3760      5381            8222       347
#
# Crimes  LARCENY  LARCENY FROM AUTO  RAPE  ROBBERY - CARJACKING  \
# Years
# 2014      11382               6719   241                   156
# 2015      10671               7057   283                   287
# 2016      10459               6517   289                   413
# 2017      10789               6176   362                   568
# 2018      10693               6368   349                   481
# 2019      10618               5679   272                   581
#
# Crimes  ROBBERY - COMMERCIAL  ROBBERY - RESIDENCE  ROBBERY - STREET  SHOOTING
# Years
# 2014                     627                  468              2662       369
# 2015                     883                  439              3133       632
# 2016                     865                  529              3799       666
# 2017                    1078                  559              3964       703
# 2018                     913                  513              3596       677
# 2019                     753                  414              3359       767

# %%
# Aggregates of Crime Types across years

fig_crime = px.line(crimes, title="Crime Types against Years")
fig_crime.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6c979a58-8ec2-4734-bb04-c5f9c288fda9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c979a58-8ec2-4734-bb04-c5f9c288fda9")) {                    Plotly.newPlot(                        "6c979a58-8ec2-4734-bb04-c5f9c288fda9",                        [{"hovertemplate":"Crimes=AGG. ASSAULT<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AGG. ASSAULT","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"AGG. ASSAULT","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[4264,4763,5149,5843,5604,5642],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=ARSON<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ARSON","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ARSON","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[216,289,268,265,126,106],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=AUTO THEFT<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AUTO THEFT","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"AUTO THEFT","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[3652,4565,4612,4669,4226,3760],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=BURGLARY<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"BURGLARY","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BURGLARY","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[6877,7856,7392,8094,6212,5381],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=COMMON ASSAULT<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"COMMON ASSAULT","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"COMMON ASSAULT","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[7463,6992,7498,8751,8369,8222],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=HOMICIDE<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"HOMICIDE","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"HOMICIDE","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[211,342,318,342,309,347],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=LARCENY<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LARCENY","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"LARCENY","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[11382,10671,10459,10789,10693,10618],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=LARCENY FROM AUTO<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LARCENY FROM AUTO","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"LARCENY FROM AUTO","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[6719,7057,6517,6176,6368,5679],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=RAPE<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"RAPE","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RAPE","orientation":"v","showlegend":true,"x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[241,283,289,362,349,272],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=ROBBERY - CARJACKING<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ROBBERY - CARJACKING","line":{"color":"#FECB52","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines", ...

# %%
#Alternate representation using bar chart

fig_bar = px.bar(crimes, title="Crime Types against Years")
fig_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6c5bf388-9a58-4e75-879f-878cb7f49cd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c5bf388-9a58-4e75-879f-878cb7f49cd8")) {                    Plotly.newPlot(                        "6c5bf388-9a58-4e75-879f-878cb7f49cd8",                        [{"alignmentgroup":"True","hovertemplate":"Crimes=AGG. ASSAULT<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AGG. ASSAULT","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"AGG. ASSAULT","offsetgroup":"AGG. ASSAULT","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[4264,4763,5149,5843,5604,5642],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=ARSON<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ARSON","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ARSON","offsetgroup":"ARSON","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[216,289,268,265,126,106],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=AUTO THEFT<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AUTO THEFT","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"AUTO THEFT","offsetgroup":"AUTO THEFT","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[3652,4565,4612,4669,4226,3760],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=BURGLARY<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"BURGLARY","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"BURGLARY","offsetgroup":"BURGLARY","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[6877,7856,7392,8094,6212,5381],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=COMMON ASSAULT<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"COMMON ASSAULT","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"COMMON ASSAULT","offsetgroup":"COMMON ASSAULT","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[7463,6992,7498,8751,8369,8222],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=HOMICIDE<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"HOMICIDE","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"HOMICIDE","offsetgroup":"HOMICIDE","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[211,342,318,342,309,347],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=LARCENY<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LARCENY","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"LARCENY","offsetgroup":"LARCENY","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[11382,10671,10459,10789,10693,10618],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=LARCENY FROM AUTO<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LARCENY FROM AUTO","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"LARCENY FROM AUTO","offsetgroup":"LARCENY FROM AUTO","orientation":"v","showlegend":true,"textposition":"auto","x":[2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[6719,7057,6517,6176,6368,5679],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=RAPE<br>Years=%{x}<br>value=%{y}<extra></extra>","legendgroup":"RAPE","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"RAPE","offsetgroup":"RAPE","orientation":"v","showlegend":true,"textposition":"auto","x":[20 ...

# %% [markdown]
# #### **Question 4**
#
# Generate a series of plots to illustrate how crime types distributions might vary from year-to-year, month-to-month, or by day-of-week aggregating across all locations

# %% [markdown]
# **NOTE:** The by the year crimes plot is already given above. Below are the plots for the by the month and by the week day distributions.

# %%
# Generate an array to capture the Crime Types against Mnnths

crime_series = []
for month in df_month.groups.keys():
    temp_group = df_month.get_group(month)
    temp_group = temp_group['Description'].value_counts()
    temp_group.rename(month, inplace=True)
    crime_series.append(temp_group)

# %%
crimes = pd.DataFrame()

for crime in crime_series:
    crimes = pd.concat([crimes,crime],axis=1)

crimes = crimes.T
crimes.rename(index=months, inplace=True)
crimes.rename_axis('Crimes',axis='columns', inplace=True)
crimes.rename_axis('Months',axis='rows',inplace=True)
crimes
# Out:
# Crimes  AGG. ASSAULT  ARSON  AUTO THEFT  BURGLARY  COMMON ASSAULT  HOMICIDE  \
# Months
# Jan             2217     86        2367      3463            3518       147
# Feb             1865     71        1711      2683            3330       103
# Mar             2414     88        1812      2836            3956       108
# Apr             2758    141        1916      3382            4115       147
# May             3017    132        2081      3528            4374       180
# Jun             2937    119        2275      3631            4261       155
# Jul             2966    123        2424      3740            3972       204
# Aug             2956    102        2302      3671            3965       179
# Sep             2778    108        2099      3747            4191       173
# Oct             2657    109        2221      3934            4226       175
# Nov             2376    107        2157      3554            3764       139
# Dec             2324     84        2119      3643            3623       159
#
# Crimes  LARCENY  LARCENY FROM AUTO  RAPE  ROBBERY - CARJACKING  \
# Months
# Jan        4840               2951   139                   225
# Feb        4124               2236   128                   148
# Mar        4822               2574   162                   148
# Apr        5214               2818   172                   183
# May        5881               3209   166                   172
# Jun        5794               3479   172                   193
# Jul        5883               3617   157                   263
# Aug        6008               3828   161                   251
# Sep        5821               3467   142                   189
# Oct        5747               3845   158                   225
# Nov        5182               3379   119                   253
# Dec        5296               3113   120                   236
#
# Crimes  ROBBERY - COMMERCIAL  ROBBERY - RESIDENCE  ROBBERY - STREET  SHOOTING
# Months
# Jan                      495                  265              1605       251
# Feb                      313                  174              1243       166
# Mar                      374                  239              1267       236
# Apr                      318                  199              1413       285
# May                      424                  265              1869       386
# Jun                      453                  244              1650       378
# Jul                      457                  251              1882       413
# Aug                      413                  301              1996       435
# Sep                      417                  209              1955       339
# Oct                      455                  278              2014       347
# Nov                      512                  237              1881       257
# Dec                      488                  260              1738       321

# %%
# Aggregates of Crime Types across months

fig_crime_months = px.line(crimes, title="Crime Types against Months")
fig_crime_months.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6f329def-4515-4283-aa9e-df367c4b114d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f329def-4515-4283-aa9e-df367c4b114d")) {                    Plotly.newPlot(                        "6f329def-4515-4283-aa9e-df367c4b114d",                        [{"hovertemplate":"Crimes=AGG. ASSAULT<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AGG. ASSAULT","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"AGG. ASSAULT","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[2217,1865,2414,2758,3017,2937,2966,2956,2778,2657,2376,2324],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=ARSON<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ARSON","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ARSON","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[86,71,88,141,132,119,123,102,108,109,107,84],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=AUTO THEFT<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AUTO THEFT","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"AUTO THEFT","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[2367,1711,1812,1916,2081,2275,2424,2302,2099,2221,2157,2119],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=BURGLARY<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"BURGLARY","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BURGLARY","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[3463,2683,2836,3382,3528,3631,3740,3671,3747,3934,3554,3643],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=COMMON ASSAULT<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"COMMON ASSAULT","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"COMMON ASSAULT","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[3518,3330,3956,4115,4374,4261,3972,3965,4191,4226,3764,3623],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=HOMICIDE<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"HOMICIDE","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"HOMICIDE","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[147,103,108,147,180,155,204,179,173,175,139,159],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=LARCENY<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LARCENY","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"LARCENY","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[4840,4124,4822,5214,5881,5794,5883,6008,5821,5747,5182,5296],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=LARCENY FROM AUTO<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LARCENY FROM AUTO","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"LARCENY FROM AUTO","orientation":"v","showlegend":true,"x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[2951,2236,2574,2818,3209,3479,3617,3828,3467,3845,3379,3113],"yaxis":"y","type":" ...

# %%
#Alternate representation using bar chart

fig_crime_months_bar = px.bar(crimes, title="Crime Types against Months")
fig_crime_months_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1826bc92-72e6-4c54-af8f-e5b46330d303" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1826bc92-72e6-4c54-af8f-e5b46330d303")) {                    Plotly.newPlot(                        "1826bc92-72e6-4c54-af8f-e5b46330d303",                        [{"alignmentgroup":"True","hovertemplate":"Crimes=AGG. ASSAULT<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AGG. ASSAULT","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"AGG. ASSAULT","offsetgroup":"AGG. ASSAULT","orientation":"v","showlegend":true,"textposition":"auto","x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[2217,1865,2414,2758,3017,2937,2966,2956,2778,2657,2376,2324],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=ARSON<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ARSON","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ARSON","offsetgroup":"ARSON","orientation":"v","showlegend":true,"textposition":"auto","x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[86,71,88,141,132,119,123,102,108,109,107,84],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=AUTO THEFT<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AUTO THEFT","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"AUTO THEFT","offsetgroup":"AUTO THEFT","orientation":"v","showlegend":true,"textposition":"auto","x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[2367,1711,1812,1916,2081,2275,2424,2302,2099,2221,2157,2119],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=BURGLARY<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"BURGLARY","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"BURGLARY","offsetgroup":"BURGLARY","orientation":"v","showlegend":true,"textposition":"auto","x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[3463,2683,2836,3382,3528,3631,3740,3671,3747,3934,3554,3643],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=COMMON ASSAULT<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"COMMON ASSAULT","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"COMMON ASSAULT","offsetgroup":"COMMON ASSAULT","orientation":"v","showlegend":true,"textposition":"auto","x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[3518,3330,3956,4115,4374,4261,3972,3965,4191,4226,3764,3623],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=HOMICIDE<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"HOMICIDE","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"HOMICIDE","offsetgroup":"HOMICIDE","orientation":"v","showlegend":true,"textposition":"auto","x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[147,103,108,147,180,155,204,179,173,175,139,159],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=LARCENY<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LARCENY","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"LARCENY","offsetgroup":"LARCENY","orientation":"v","showlegend":true,"textposition":"auto","x":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"xaxis":"x","y":[4840,4124,4822,5214,5881,5794,5883,6008,5821,5747,5182,5296],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=LARCENY FROM AUTO<br>Months=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LARCENY FROM AUTO","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"LA ...

# %%
# Generate an array to capture the Crime Types against Days

crime_series = []
for day in df_week.groups.keys():
    temp_group = df_week.get_group(day)
    temp_group = temp_group['Description'].value_counts()
    temp_group.rename(day, inplace=True)
    crime_series.append(temp_group)

crimes = pd.DataFrame()

for crime in crime_series:
    crimes = pd.concat([crimes,crime],axis=1)

crimes = crimes.T
crimes.rename(index=days_of_week, inplace=True)
crimes.rename_axis('Crimes',axis='columns', inplace=True)
crimes.rename_axis('Days',axis='rows',inplace=True)

# %%
# Aggregates of Crime Types across days

fig_crime_days = px.line(crimes, title="Crime Types against Days")
fig_crime_days.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="18a7fa87-8443-4997-9d9d-5011ec70b657" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18a7fa87-8443-4997-9d9d-5011ec70b657")) {                    Plotly.newPlot(                        "18a7fa87-8443-4997-9d9d-5011ec70b657",                        [{"hovertemplate":"Crimes=AGG. ASSAULT<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AGG. ASSAULT","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"AGG. ASSAULT","orientation":"v","showlegend":true,"x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[4470,4458,4269,4196,4407,4798,4667],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=ARSON<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ARSON","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ARSON","orientation":"v","showlegend":true,"x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[203,179,170,177,157,194,190],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=AUTO THEFT<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AUTO THEFT","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"AUTO THEFT","orientation":"v","showlegend":true,"x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[3718,3662,3623,3521,3740,3574,3646],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=BURGLARY<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"BURGLARY","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BURGLARY","orientation":"v","showlegend":true,"x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[6451,6355,6275,6252,6626,5142,4711],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=COMMON ASSAULT<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"COMMON ASSAULT","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"COMMON ASSAULT","orientation":"v","showlegend":true,"x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[6621,6481,6420,6523,6873,7152,7225],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=HOMICIDE<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"HOMICIDE","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"HOMICIDE","orientation":"v","showlegend":true,"x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[264,291,280,271,249,258,256],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=LARCENY<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LARCENY","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"LARCENY","orientation":"v","showlegend":true,"x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[9561,9502,9649,9664,10155,8479,7602],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=LARCENY FROM AUTO<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LARCENY FROM AUTO","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"LARCENY FROM AUTO","orientation":"v","showlegend":true,"x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[5580,5489,5509,5518,5637,5275,5508],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=RAPE<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"RAPE","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"RAPE","orientation":"v","showlegend":true,"x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[296,244,216,234,272,296,238],"yaxis":"y","type":"scatter"},{"hovertemplate":"Crimes=ROBBERY - CARJACKING<br>Days=%{x}<br>value=%{y}<extr ...

# %%
#Alternate representation using bar chart

fig_crime_days_bar = px.bar(crimes, title="Crime Types against Days")
fig_crime_days_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fd56c9ad-703a-4888-94e2-1f57ed198909" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd56c9ad-703a-4888-94e2-1f57ed198909")) {                    Plotly.newPlot(                        "fd56c9ad-703a-4888-94e2-1f57ed198909",                        [{"alignmentgroup":"True","hovertemplate":"Crimes=AGG. ASSAULT<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AGG. ASSAULT","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"AGG. ASSAULT","offsetgroup":"AGG. ASSAULT","orientation":"v","showlegend":true,"textposition":"auto","x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[4470,4458,4269,4196,4407,4798,4667],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=ARSON<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"ARSON","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ARSON","offsetgroup":"ARSON","orientation":"v","showlegend":true,"textposition":"auto","x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[203,179,170,177,157,194,190],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=AUTO THEFT<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"AUTO THEFT","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"AUTO THEFT","offsetgroup":"AUTO THEFT","orientation":"v","showlegend":true,"textposition":"auto","x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[3718,3662,3623,3521,3740,3574,3646],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=BURGLARY<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"BURGLARY","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"BURGLARY","offsetgroup":"BURGLARY","orientation":"v","showlegend":true,"textposition":"auto","x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[6451,6355,6275,6252,6626,5142,4711],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=COMMON ASSAULT<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"COMMON ASSAULT","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"COMMON ASSAULT","offsetgroup":"COMMON ASSAULT","orientation":"v","showlegend":true,"textposition":"auto","x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[6621,6481,6420,6523,6873,7152,7225],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=HOMICIDE<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"HOMICIDE","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"HOMICIDE","offsetgroup":"HOMICIDE","orientation":"v","showlegend":true,"textposition":"auto","x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[264,291,280,271,249,258,256],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=LARCENY<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LARCENY","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"LARCENY","offsetgroup":"LARCENY","orientation":"v","showlegend":true,"textposition":"auto","x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[9561,9502,9649,9664,10155,8479,7602],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=LARCENY FROM AUTO<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"LARCENY FROM AUTO","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"LARCENY FROM AUTO","offsetgroup":"LARCENY FROM AUTO","orientation":"v","showlegend":true,"textposition":"auto","x":["Mon","Tue","Wed","Thu","Fri","Sat","Sun"],"xaxis":"x","y":[5580,5489,5509,5518,5637,5275,5508],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Crimes=RAPE<br>Days=%{x}<br>value=%{y}<extra></extra>","legendgroup":"RAPE","marker":{"color":"#FF97FF","pat ...

# %% [markdown]
# #### **Question 5**
#
# Design a dashboard that allows users like Gary to explore the spatial and temporal patterns of crime. You may get inspiration from tasks 2-4, but feel free to add additional bringing in additional insights. **Bonus: Create a real dynamic dashboard that allows users to change parameters such as location and time period.**

# %%
# Lets add another column which captures just the Years. This will be used for animation slider.

df['Year'] = df['Date'].dt.year

# Now lets group against the Crime Types

df_crimes = df.groupby('Description')

# %%
# We need to capture all the grouped dataframes of crime types in a dictionary so that we can use it in the interactive plotting

crime_types = {}
for crime_type in df_crimes.groups.keys():
    crime_t = df_crimes.get_group(crime_type)
    crime_t_sorted = crime_t.sort_values('Year', ascending=True)
    crime_types.update({crime_type:crime_t_sorted})

# %%
crime_types.keys()
# Out:
# dict_keys(['AGG. ASSAULT', 'ARSON', 'AUTO THEFT', 'BURGLARY', 'COMMON ASSAULT', 'HOMICIDE', 'LARCENY', 'LARCENY FROM AUTO', 'RAPE', 'ROBBERY - CARJACKING', 'ROBBERY - COMMERCIAL', 'ROBBERY - RESIDENCE', 'ROBBERY - STREET', 'SHOOTING'])

# %%
# Sample of the ARSON crime type across years. This can be changed to any of the values from the above dictionary
crime_types.get('ARSON')
# Out:
#          CrimeDate CrimeTime CrimeCode             Location Description  \
# 292135  01/06/2014  15:16:00       8FO       1300 W 36TH ST       ARSON
# 263341  08/28/2014  16:37:00       8AO  300 E UNIVERSITY PW       ARSON
# 263205  08/29/2014  13:49:00        8H    5000 E HOFFMAN ST       ARSON
# 261904  09/08/2014   2:28:00        8H      500 KINGSTON RD       ARSON
# 261869  09/08/2014  17:20:00        8J      1600 WILKENS AV       ARSON
# ...            ...       ...       ...                  ...         ...
# 35321   05/05/2019   5:02:00        8H   3300 SPAULDING AVE       ARSON
# 36143   04/28/2019   1:30:00       8BO   2900 EDMONDSON AVE       ARSON
# 36144   04/28/2019   1:30:00       8BO   2900 EDMONDSON AVE       ARSON
# 36521   04/26/2019  10:50:00        8J       1700 E 25TH ST       ARSON
# 4406    12/25/2019   3:45:00        8H      1100 ANDOVER RD       ARSON
#
#        Inside_Outside Weapon   District               Neighborhood  Longitude  \
# 292135              I   FIRE   NORTHERN                    HAMPDEN -76.636488
# 263341              I   FIRE   NORTHERN                 OAKENSHAWE -76.613518
# 263205              O   FIRE  NORTHEAST          ARMISTEAD GARDENS -76.556377
# 261904              O   FIRE  SOUTHWEST                   WESTGATE -76.709514
# 261869              O   FIRE   SOUTHERN  NEW SOUTHWEST/MOUNT CLARE -76.642350
# ...               ...    ...        ...                        ...        ...
# 35321               O   FIRE  NORTHWEST       CENTRAL PARK HEIGHTS -76.676148
# 36143               O   FIRE  SOUTHWEST          FRANKLINTOWN ROAD -76.665103
# 36144             NaN   FIRE  SOUTHWEST          FRANKLINTOWN ROAD -76.665103
# 36521               I   FIRE    EASTERN                DARLEY PARK -76.592970
# 4406              NaN   FIRE  NORTHEAST       EDNOR GARDENS-LAKESI -76.600083
#
#          Latitude               Premise                Date  Year
# 292135  39.330646                SCHOOL 2014-01-06 15:16:00  2014
# 263341  39.329917  APT/CONDO - OCCUPIED 2014-08-28 16:37:00  2014
# 263205  39.307609                 ALLEY 2014-08-29 13:49:00  2014
# 261904  39.286582                STREET 2014-09-08 02:28:00  2014
# 261869  39.283596                  YARD 2014-09-08 17:20:00  2014
# ...           ...                   ...                 ...   ...
# 35321   39.347367                STREET 2019-05-05 05:02:00  2019
# 36143   39.294536                STREET 2019-04-28 01:30:00  2019
# 36144   39.294536                   NaN 2019-04-28 01:30:00  2019
# 36521   39.315781     ROW/TOWNHOUSE-OCC 2019-04-26 10:50:00  2019
# 4406    39.336679                   NaN 2019-12-25 03:45:00  2019
#
# [1270 rows x 14 columns]

# %% [markdown]
# #### **Interactive Dashboard Instructions** : Cell below output shows a drop down of all crime types. By selecting different drop down options, the plot can be changed to that crime type. After changing the crime type, run the next cell again to see the dashboard change for the crime type selected.

# %%
# Now we will use the ipy widget for selection to populate a selection control with the crime types for options to be selected

crime_dropD = widgets.Dropdown(
    options=[crime_type for crime_type in crime_types.keys()],
    value='AGG. ASSAULT',
    description='Select Crime Type',
    disabled=False,
    )

# Display the control
display(crime_dropD)
# Out:
# Dropdown(description='Select Crime Type', options=('AGG. ASSAULT', 'ARSON', 'AUTO THEFT', 'BURGLARY', 'COMMON …

# %% [markdown]
# #### **Run the below cell again after changing the option in the drop down above. Press the "Play" button at the bottom of the map to see an animation of the crime densities across the years. There is also a slider which can be moved to show the temporal and geographical patters. Map can be moved around and zoomed in and out.**

# %%
# This code block generates a mapbox using the Plotly function for density map box with an interactive animation slider and play button for animation

mapbox_title = "Crime Types Temporal and Spatial Distributions - " + crime_dropD.value

fig_crimes_geo = px.density_mapbox(crime_types.get(crime_dropD.value), lat='Latitude', lon='Longitude', radius=10,
                        center=dict(lat=39.299236, lon=-76.609383), zoom=11, title=mapbox_title,
                        mapbox_style="open-street-map", height=900, width=1050,animation_frame="Year", hover_name="Neighborhood")
fig_crimes_geo.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a47048b2-c83a-4d60-bfe3-cf2bd3eb6c41" class="plotly-graph-div" style="height:900px; width:1050px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a47048b2-c83a-4d60-bfe3-cf2bd3eb6c41")) {                    Plotly.newPlot(                        "a47048b2-c83a-4d60-bfe3-cf2bd3eb6c41",                        [{"coloraxis":"coloraxis","hovertemplate":"<b>%{hovertext}</b><br><br>Year=2014<br>Latitude=%{lat}<br>Longitude=%{lon}<extra></extra>","hovertext":["CURTIS BAY INDUSTRIAL AREA","BELAIR-EDISON","RESERVOIR HILL","COLDSTREAM HOMESTEAD","BROOKLYN","WINSTON-GOVANS","WILSON PARK","MILTON-MONTFORD","FRANKLIN SQUARE","FRANKFORD","DRUID HEIGHTS","BELAIR-EDISON","EDMONDSON VILLAGE","CENTRAL PARK HEIGHTS","CENTRAL PARK HEIGHTS","EAST BALTIMORE MIDWA","FRANKLINTOWN ROAD","WESTFIELD","CEDONIA","MEDFORD/BROENING MAN","SETON HILL","SETON HILL","MCELDERRY PARK","CENTRAL PARK HEIGHTS","CHARLES NORTH","PENROSE/FAYETTE ST OUTREACH","COLDSTREAM HOMESTEAD","MEDFORD","CENTRAL PARK HEIGHTS","FRANKFORD",null,"OLIVER","EAST ARLINGTON","PENROSE/FAYETTE ST OUTREACH","LUCILLE PARK","MIDTOWN EDMONDSON",null,"WAVERLY","IRVINGTON","WOODBOURNE MCCABE","MIDTOWN EDMONDSON","DORCHESTER/GRAN-BARR","ORANGEVILLE","S.B.I.C.","OLIVER","OLIVER","GLENHAM-BELFORD","CLIFTON PARK","NORTHWEST COMMUNITY","WEST ARLINGTON","FRANKFORD","MOUNT HOLLY","MEDFORD/BROENING MAN","CHARLES VILLAGE","TEN HILLS","COLDSTREAM HOMESTEAD","UPTON","PARKLANE","FRANKFORD","EAST BALTIMORE MIDWA","CROSS COUNTRY","UPTON","DOLFIELD","MADISON EASTEND","HANLON/LONGWOOD","ALLENDALE","MADISON EASTEND","EAST BALTIMORE MIDWA","LUCILLE PARK","HARLEM PARK","BELAIR-EDISON","MOUNT HOLLY","BROOKLYN","PENN NORTH","ABELL","BROOKLYN","SHIPLEY HILL","ALLENDALE","WESTPORT","NORTHWEST COMMUNITY","BROADWAY EAST","BALTIMORE HIGHLANDS","DARLEY PARK","FALLSTAFF","PARKSIDE","FELLS POINT","ARLINGTON","ARLINGTON",null,"PENN NORTH","DUNBAR","PENN NORTH","LOCH RAVEN","COLDSTREAM HOMESTEAD","JONES FALLS AREA","HOWARD PARK","BELAIR-EDISON","HOWARD PARK","FRANKFORD","SHIPLEY HILL","BELAIR-EDISON","JONES FALLS AREA","PARK CIRCLE","CALLAWAY-GARRISON","DOLFIELD","CURTIS BAY INDUSTRIAL AREA","MONDAWMIN","DOWNTOWN","UPTON","EDNOR GARDENS-LAKESI","WAVERLY","MCELDERRY PARK","LANGSTON HUGHES","WESTPORT","EDMONDSON VILLAGE","FALLSTAFF","NORTHWEST COMMUNITY","WEST ARLINGTON","BEREA","BROOKLYN","FELLS POINT","ODONNELL HEIGHTS","BEREA","HOLLINS PARK","DARLEY PARK","BROADWAY EAST","WINSTON-GOVANS","PULASKI INDUSTRIAL AREA","WINDSOR HILLS","MADISON EASTEND",null,"HUDSON-HIGHLANDTOWN","NEW SOUTHWEST/MOUNT CLARE","BROADWAY EAST","BROADWAY EAST","BELAIR-EDISON","COPPIN HEIGHTS/ASHBU","PARKLANE","FOREST PARK","FRANKFORD","CARROLLTON RIDGE","HARFORD-ECHODALE-PER","SHIPLEY HILL","CHARLES NORTH","MOUNT VERNON","EAST ARLINGTON","PARK CIRCLE","HARWOOD","MONDAWMIN","COLDSTREAM HOMESTEAD","PENROSE/FAYETTE ST OUTREACH","WAVERLY","ARLINGTON","IRVINGTON","CANTON","NEW SOUTHWEST/MOUNT CLARE","BROADWAY EAST","MIDTOWN EDMONDSON","WESTPORT","SOUTH CLIFTON PARK",null,"COLDSTREAM HOMESTEAD","PARK CIRCLE","LOYOLA/NOTRE DAME","BROADWAY EAST","BELAIR-PARKSIDE","RICHNOR SPRINGS","OLIVER","CARROLLTON RIDGE","SAINT JOSEPHS","STONEWOOD-PENTWOOD-W","ASHBURTON",null,"EDMONDSON VILLAGE","WASHINGTON VILLAGE","EDMONDSON VILLAGE","REISTERSTOWN STATION","CONCERNED CITIZENS O","MILL HILL","PENN NORTH","JOSEPH LEE","CENTRAL PARK HEIGHTS","CHERRY HILL","RESERVOIR HILL",null,"BROADWAY EAST","HOLLINS PARK","MONDAWMIN","SANDTOWN-WINCHESTER","MOUNT WINANS","SANDTOWN-WINCHESTER","MCELDERRY PARK","HARFORD-ECHODALE-PER","MOUNT HOLLY","SAINT AGNES","WESTPORT","BROADWAY EAST","FRANKFORD","DOWNTOWN","MID-TOWN BELVEDERE","BELAIR-EDISON","DOWNTOWN","MILL HILL","NORTHWEST COMMUNITY","UNION SQUARE","MOSHER","GREENSPRING","GAY STREET","WEST ARLINGTON"," ...
